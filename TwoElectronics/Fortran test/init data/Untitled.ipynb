# %%
import numpy as np  
import matplotlib.pyplot as plt  
  
  
x = np.linspace(0, 10, 500)  
dashes = [10, 5, 100, 5] # 虚线参数，10和100是实点，5是虚点  
  
fig, ax = plt.subplots()  
line1, = ax.plot(x, np.sin(x), '--', linewidth=2, label='Dashesset retroactively')  
line1.set_dashes(dashes)   #   设置虚线参数  
line2, = ax.plot(x,-1* np.sin(x), dashes=[30, 5, 10, 5], label='Dashes set proactively')  
#  几种常用的线型的演示  
line3, = ax.plot(x, np.sin(x)/2, ':', label='..style')  
line4, = ax.plot(x,-np.sin(x)/2, '-.', label='-.style')  
line5, = ax.plot(x,np.sin(x)/4, '--', label='--style')  
line6, = ax.plot(x,-np.sin(x)/4, '^', label='--style')  
  
#ax.legend(loc='lowerright')   #   显示图例，loc设置图例位置  
plt.show()

# %%
qq  = np.loadtxt('QQ.DAT')

# %%
print(qq[0:10])
# Out:
# [1.500e-09 6.200e-09 1.390e-08 2.470e-08 3.860e-08 5.550e-08 7.560e-08
#  9.870e-08 1.249e-07 1.542e-07]

# %%
qq.shape
# Out:
# (80000,)

# %%
e_check = np.loadtxt('E_2t.DAT')

# %%
e_check.shape
# Out:
# (80000,)

# %%
print(e_check[0:10])
# Out:
# [0.000125 0.00025  0.000375 0.0005   0.000625 0.00075  0.000875 0.001
#  0.001125 0.00125 ]

# %%
e_check=e_check[:,0]

# %%
plt.plot(e_check,qq)

# %%
my_qq = np.loadtxt('DS_qq_cpu_check05122238.dat')

# %%
plt.plot(e_check,my_qq)
