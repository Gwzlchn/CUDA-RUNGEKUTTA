# %%
import numpy as np  
import matplotlib.pyplot as plt  
  
  
x = np.linspace(0, 10, 500)  
dashes = [10, 5, 100, 5] # 虚线参数，10和100是实点，5是虚点  
  
fig, ax = plt.subplots()  
line1, = ax.plot(x, np.sin(x), '--', linewidth=2, label='Dashesset retroactively')  
line1.set_dashes(dashes)   #   设置虚线参数  
line2, = ax.plot(x,-1* np.sin(x), dashes=[30, 5, 10, 5], label='Dashes set proactively')  
#  几种常用的线型的演示  
line3, = ax.plot(x, np.sin(x)/2, ':', label='..style')  
line4, = ax.plot(x,-np.sin(x)/2, '-.', label='-.style')  
line5, = ax.plot(x,np.sin(x)/4, '--', label='--style')  
line6, = ax.plot(x,-np.sin(x)/4, '^', label='--style')  
  
#ax.legend(loc='lowerright')   #   显示图例，loc设置图例位置  
plt.show()

# %%
my_first = np.loadtxt('OneStep.dat')

# %%
first_x1 = my_first[:,0]
first_y1 = my_first[:,1]
first_z1 = my_first[:,2]
first_px1 = my_first[:,3]
first_py1 = my_first[:,4]
first_pz1 = my_first[:,5]
first_x2 = my_first[:,6]
first_y2 = my_first[:,7]
first_z2 = my_first[:,8]
first_px2 = my_first[:,9]
first_py2 = my_first[:,10]
first_pz2 = my_first[:,11]

# %%
plt.scatter(first_py1,first_pz1,s=1,c='black',marker='.')
plt.xlim((-3, 3))
plt.ylim((-3, 3))
# Out:
# (-3, 3)

# %%
other_first = np.loadtxt('test-n.DAT')
first_x1 = other_first[:,0]
first_y1 = other_first[:,1]
first_z1 = other_first[:,2]
first_px1 = other_first[:,3]
first_py1 = other_first[:,4]
first_pz1 = other_first[:,5]
first_x2 = other_first[:,6]
first_y2 = other_first[:,7]
first_z2 = other_first[:,8]
first_px2 = other_first[:,9]
first_py2 = other_first[:,10]
first_pz2 = other_first[:,11]
plt.scatter(first_py1,first_pz1,s=1,c='black',marker='.')
plt.xlim((-3, 3))
plt.ylim((-3, 3))
# Out:
# (-3, 3)

# %%
plt.scatter(first_px1,first_py1,s=1,c='black',marker='.')
plt.xlim((-2, 2))
plt.ylim((-2, 2))
# Out:
# (-2, 2)
